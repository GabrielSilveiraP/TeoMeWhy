# %%
import pandas as pd
import glob
import os

# %%
arquivos = glob.glob("C:/Users/bielz/Documents/MeusProjetos/TeomeWhy/pandas-2025-main/data/ipea/*")

# %%
print(arquivos)
# Out:
# ['C:/Users/bielz/Documents/MeusProjetos/TeomeWhy/pandas-2025-main/data/ipea\\homicidio-de-jovens-por-armas-de-fogo.csv', 'C:/Users/bielz/Documents/MeusProjetos/TeomeWhy/pandas-2025-main/data/ipea\\homicidios-de-homens-por-armas-de-fogo.csv', 'C:/Users/bielz/Documents/MeusProjetos/TeomeWhy/pandas-2025-main/data/ipea\\homicidios-de-jovens-homens.csv', 'C:/Users/bielz/Documents/MeusProjetos/TeomeWhy/pandas-2025-main/data/ipea\\homicidios-de-jovens-mulheres.csv', 'C:/Users/bielz/Documents/MeusProjetos/TeomeWhy/pandas-2025-main/data/ipea\\homicidios-de-jovens.csv', 'C:/Users/bielz/Documents/MeusProjetos/TeomeWhy/pandas-2025-main/data/ipea\\homicidios-de-mulheres-por-armas-de-fogo.csv', 'C:/Users/bielz/Documents/MeusProjetos/TeomeWhy/pandas-2025-main/data/ipea\\homicidios-homens-nao-negros.csv', 'C:/Users/bielz/Documents/MeusProjetos/TeomeWhy/pandas-2025-main/data/ipea\\homicidios-homens-negros.csv', 'C:/Users/bielz/Documents/MeusProjetos/TeomeWhy/pandas-2025-main/data/ipea\\homicidios-hom
# ...

# %%
DataFrameInteiro = pd.concat(
    [pd.read_csv(f, sep = ";") for f in arquivos],
    ignore_index=True, 
    axis=0
)

# %%
DataFrameInteiro
# Out:
#        cod nome  período  valor
# 0       53   DF     1989    116
# 1       35   SP     1989   1821
# 2       33   RJ     1989   1722
# 3       32   ES     1989    180
# 4       31   MG     1989    223
# ...    ...  ...      ...    ...
# 13927   23   CE     2021   3471
# 13928   22   PI     2021    766
# 13929   21   MA     2021   1999
# 13930   17   TO     2021    441
# 13931   53   DF     2021    401
#
# [13932 rows x 4 columns]

# %%
os.makedirs("C:/Users/bielz/Documents/MeusProjetos/ScriptTestepIntelbras", exist_ok=True)

# %%
dataframeInteiro.to_csv(
    "C:/Users/bielz/Documents/MeusProjetos/ScriptTestepIntelbras/dataFrameFalsoDasConversa.csv",
    index=False,
    sep=";"
)
